# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
# %matplotlib inline

# %%
imagen = mpimg.imread('escom.jpg')
print(imagen)

print('Imagen tipo: ', type(imagen),' de dimeniones: ', imagen.shape)
plt.imshow(imagen)
# Out:
# [[[177 192 161]
#   [155 170 137]
#   [127 145 107]
#   ...,
#   [141 171 109]
#   [137 167 105]
#   [133 163 103]]
#
#  [[118 136  96]
#   [110 128  86]
#   [103 122  77]
#   ...,
#   [139 169 105]
#   [135 165 103]
#   [131 161  99]]
#
#  [[110 134  82]
#   [106 131  76]
#   [104 129  74]
#   ...,
#   [144 175 108]
#   [140 170 106]
#   [134 164 102]]
#
#  ...,
#  [[255 253 250]
#   [255 254 252]
#   [252 255 255]
#   ...,
#   [123 126 145]
#   [120 123 142]
#   [119 122 141]]
#
#  [[238 229 222]
#   [248 243 237]
#   [255 255 251]
#   ...,
#   [124 127 144]
#   [121 124 143]
#   [120 123 142]]
#
#  [[151 138 129]
#   [178 169 160]
#   [180 176 167]
#   ...,
#   [125 128 145]
#   [122 125 142]
#   [120 123 140]]]
# Imagen tipo:  <class 'numpy.ndarray'>  de dimeniones:  (1044, 1155, 3)

# %%
b,r,g=cv2.split(imagen)
plt.imshow(r,cmap='gray')

# %%
plt.imshow(b,cmap='gray')

# %%
plt.imshow(g,cmap='gray')

# %%
imgResta = g - r
plt.imshow(imgResta, cmap='gray')

# %%
imgSuma = g + r
plt.imshow(imgSuma,cmap='gray')

# %%
imgNDI = imgResta / imgSuma
plt.imshow(imgNDI, cmap='gray')
# Out:
# /home/brandon/conda3/envs/vision_env/lib/python3.5/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# /home/brandon/conda3/envs/vision_env/lib/python3.5/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
